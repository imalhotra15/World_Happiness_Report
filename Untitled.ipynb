# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_1 = pd.read_csv("C:/Users/ishaa/Python_Scripts/Kaggle/World Happiness Report 2/2015.csv")
df_2 = pd.read_csv("C:/Users/ishaa/Python_Scripts/Kaggle/World Happiness Report 2/2016.csv")
df_3 = pd.read_csv("C:/Users/ishaa/Python_Scripts/Kaggle/World Happiness Report 2/2017.csv")
df_4 = pd.read_csv("C:/Users/ishaa/Python_Scripts/Kaggle/World Happiness Report 2/2018.csv")
df_5 = pd.read_csv("C:/Users/ishaa/Python_Scripts/Kaggle/World Happiness Report 2/2019.csv")

df_1['Year'] = 2015
df_2['Year'] = 2016
df_3['Year'] = 2017
df_4['Year'] = 2018
df_5['Year'] = 2019

# %%
aa = df_5.isnull().sum()

# %%
(pd.Series([df_1.columns , df_2.columns , df_3.columns , df_4.columns , df_5.columns]))
# Out:
# 0    Index(['Country', 'Region', 'Happiness Rank', ...
# 1    Index(['Country', 'Region', 'Happiness Rank', ...
# 2    Index(['Country', 'Happiness.Rank', 'Happiness...
# 3    Index(['Overall rank', 'Country or region', 'S...
# 4    Index(['Overall rank', 'Country or region', 'S...
# dtype: object

# %%
df_1.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
df_all = pd.concat([df_1 , df_2 , df_3 , df_3 , df_4 , df_5])

# %%
df_all.isnull().sum()
# Out:
# Country                          312
# Region                           622
# Happiness Rank                   622
# Happiness Score                  622
# Standard Error                   779
# Economy (GDP per Capita)         622
# Family                           312
# Health (Life Expectancy)         622
# Freedom                          312
# Trust (Government Corruption)    622
# Generosity                         0
# Dystopia Residual                622
# Year                               0
# Lower Confidence Interval        780
# Upper Confidence Interval        780
# Happiness.Rank                   627
# Happiness.Score                  627
# Whisker.high                     627
# Whisker.low                      627
# Economy..GDP.per.Capita.         627
# Health..Life.Expectancy.         627
# Trust..Government.Corruption.    627
# Dystopia.Residual                627
# Overall rank                     625
# Country or region                625
# ...

# %%
df_all
# Out:
#          Country          Region  Happiness Rank  Happiness Score  \
# 0    Switzerland  Western Europe             1.0            7.587
# 1        Iceland  Western Europe             2.0            7.561
# 2        Denmark  Western Europe             3.0            7.527
# 3         Norway  Western Europe             4.0            7.522
# 4         Canada   North America             5.0            7.427
# ..           ...             ...             ...              ...
# 151          NaN             NaN             NaN              NaN
# 152          NaN             NaN             NaN              NaN
# 153          NaN             NaN             NaN              NaN
# 154          NaN             NaN             NaN              NaN
# 155          NaN             NaN             NaN              NaN
#
#      Standard Error  Economy (GDP per Capita)   Family  \
# 0           0.03411                   1.39651  1.34951
# 1           0.04884                   1.30232  1.40223
# ...

# %%
df = df_all
mask1 = df['Year'] == 2015
plt.bar(range( df['Happiness Rank'][mask1].size) , df['Happiness Score'][mask1])
# Out:
# <BarContainer object of 158 artists>

# %%
data1 = df_all
x1 = 'Region'
y1 = 'Happiness Score'
plt.figure(figsize = (30,10))
plt.title(y1)

sns.violinplot(data = data1 , x = x1 , y = y1 ,
              scale = "width")
# sns.swarmplot(data = data1 , x = x1 , y = y1 )

# %%
data1 = df_all[df_all['Region']=='Southern Asia']
x1 = 'Country'
y1 = 'Happiness Score'
plt.figure(figsize = (30,10))
plt.title(y1+'-South Asia')

sns.violinplot(data = data1 , x = x1 , y = y1 ,
              scale = "width")
# sns.swarmplot(data = data1 , x = x1 , y = y1 )

# %%
df_all.dataframeName
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-8aef4256262b> in <module>
# ----> 1 df_all.dataframeName
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'dataframeName'

# %%
corr = df_1.corr()
corr.style.background_gradient(cmap='coolwarm').set_properties(**{'font-size': '0pt'})
# Out:
# C:\Users\ishaa\Anaconda3\lib\site-packages\pandas\io\formats\style.py:1089: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(s.to_numpy()) if vmin is None else vmin
# C:\Users\ishaa\Anaconda3\lib\site-packages\pandas\io\formats\style.py:1090: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(s.to_numpy()) if vmax is None else vmax
# <style  type="text/css" >
#     #T_9a97c67d_c8c9_11ec_b02c_046c591d1c4drow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#             font-size:  0pt;
#         }    #T_9a97c67d_c8c9_11ec_b02c_046c591d1c4drow0_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#             font-size:  0pt;
#         }    #T_9a97c67d_c8c9_11ec_b02c_046c591d1c4drow0_col2 {
#             background-color:  #b2ccfb;
#             color:  #000000;
#             font-size:  0pt;
#         }    #T_9a97c67d_c8c9_11ec_b02c_046c591d1c4drow0_col3 {
#             background-color:  #3b4cc0;
# ...

# %%
f = plt.figure(figsize=(19, 15))

plt.matshow(df_1.corr(), fignum=f.number)
